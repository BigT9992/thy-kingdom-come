# %%
import pandas as pd

# %%
path = 'c:/datasets/BootcampSchedule.csv'

# %%
bootcampSchedule = pd.read_csv('c:/datasets/BootcampSchedule.csv')

# %%
print (bootcampSchedule)
# Out:
#        Month    Date  Bootcamp Time (EST)     Cohort         Program   \
# 0        July  07-Jul             6.00 AM  Cohort 14   Data Analytics
# 1        July  08-Jul            10.00 AM  Cohort 15  Data Science/ML
# 2        July  07-Jul             6.00 AM  Cohort 14  Data Science/ML
# 3        July  08-Jul            10.00 AM  Cohort 15   Data Analytics
# 4        July  21-Jul             6.00 AM  Cohort 14   Data Analytics
# 5        July  21-Jul            10.00 AM  Cohort 15  Data Science/ML
# 6        July  22-Jul             6.00 AM  Cohort 14  Data Science/ML
# 7        July  22-Jul            10.00 AM  Cohort 15   Data Analytics
# 8      August  04-Aug             6.00 AM  Cohort 14   Data Analytics
# 9      August  04-Aug            10.00 AM  Cohort 15  Data Science/ML
# 10     August  05-Aug             6.00 AM  Cohort 14  Data Science/ML
# 11     August  05-Aug            10.00 AM  Cohort 15   Data Analytics
# ...

# %%
bootcampSchedule.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                27 non-null     object
#  1   Date                 28 non-null     object
#  2   Bootcamp Time (EST)  28 non-null     object
#  3   Cohort               28 non-null     object
#  4   Program              28 non-null     object
#  5   Topic                28 non-null     object
# dtypes: object(6)
# memory usage: 1.4+ KB

# %%
#INFERENCE from .info()
'''
The data consists of 6 features and 28 samples. A sample is missing from the month feature
Also it contains 6 string features
'''
# Out:
# '\nThe data consists of 6 features and 28 samples. A sample is missing from the month feature\nAlso it contains 6 string features\n'

# %%
bootcampSchedule.describe().T
# Out:
#                     count unique               top freq
# Month                  27      3         September   11
# Date                   28     14            07-Jul    2
# Bootcamp Time (EST)    28      2           6.00 AM   14
# Cohort                 28      2         Cohort 14   14
# Program                28      2    Data Analytics   14
# Topic                  28     21  Python Functions    3

# %%
#Check for missing values
bootcampSchedule.isnull()
# Out:
#     Month   Date   Bootcamp Time (EST)  Cohort  Program   Topic
# 0    False  False                False   False     False   False
# 1    False  False                False   False     False   False
# 2    False  False                False   False     False   False
# 3    False  False                False   False     False   False
# 4    False  False                False   False     False   False
# 5    False  False                False   False     False   False
# 6    False  False                False   False     False   False
# 7    False  False                False   False     False   False
# 8    False  False                False   False     False   False
# 9    False  False                False   False     False   False
# 10   False  False                False   False     False   False
# 11   False  False                False   False     False   False
# 12   False  False                False   False     False   False
# ...

# %%
print (bootcampSchedule.isnull().sum())
#A value is missing from the month feature in the 27th row
# filling missing value using fillna()
# Out:
# Month                  1
# Date                   0
# Bootcamp Time (EST)    0
# Cohort                 0
# Program                0
# Topic                  0
# dtype: int64

# %%
bootcampSchedule.columns
# Out:
# Index(['Month ', 'Date ', 'Bootcamp Time (EST)', 'Cohort', 'Program ',
#        'Topic '],
#       dtype='object')

# %%
bootcampSchedule["Month "].fillna("September", inplace = True)
print(bootcampSchedule)
# Out:
#        Month    Date  Bootcamp Time (EST)     Cohort         Program   \
# 0        July  07-Jul             6.00 AM  Cohort 14   Data Analytics
# 1        July  08-Jul            10.00 AM  Cohort 15  Data Science/ML
# 2        July  07-Jul             6.00 AM  Cohort 14  Data Science/ML
# 3        July  08-Jul            10.00 AM  Cohort 15   Data Analytics
# 4        July  21-Jul             6.00 AM  Cohort 14   Data Analytics
# 5        July  21-Jul            10.00 AM  Cohort 15  Data Science/ML
# 6        July  22-Jul             6.00 AM  Cohort 14  Data Science/ML
# 7        July  22-Jul            10.00 AM  Cohort 15   Data Analytics
# 8      August  04-Aug             6.00 AM  Cohort 14   Data Analytics
# 9      August  04-Aug            10.00 AM  Cohort 15  Data Science/ML
# 10     August  05-Aug             6.00 AM  Cohort 14  Data Science/ML
# 11     August  05-Aug            10.00 AM  Cohort 15   Data Analytics
# ...

# %%
bootcampSchedule.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                28 non-null     object
#  1   Date                 28 non-null     object
#  2   Bootcamp Time (EST)  28 non-null     object
#  3   Cohort               28 non-null     object
#  4   Program              28 non-null     object
#  5   Topic                28 non-null     object
# dtypes: object(6)
# memory usage: 1.4+ KB

# %%
bootcampSchedule.describe().T
# Out:
#                     count unique               top freq
# Month                  28      3         September   12
# Date                   28     14            07-Jul    2
# Bootcamp Time (EST)    28      2           6.00 AM   14
# Cohort                 28      2         Cohort 14   14
# Program                28      2    Data Analytics   14
# Topic                  28     21  Python Functions    3

# %%
bootcampSchedule.isnull()
# Out:
#     Month   Date   Bootcamp Time (EST)  Cohort  Program   Topic
# 0    False  False                False   False     False   False
# 1    False  False                False   False     False   False
# 2    False  False                False   False     False   False
# 3    False  False                False   False     False   False
# 4    False  False                False   False     False   False
# 5    False  False                False   False     False   False
# 6    False  False                False   False     False   False
# 7    False  False                False   False     False   False
# 8    False  False                False   False     False   False
# 9    False  False                False   False     False   False
# 10   False  False                False   False     False   False
# 11   False  False                False   False     False   False
# 12   False  False                False   False     False   False
# ...

# %%
print (bootcampSchedule.isnull().sum())
# Out:
# Month                  0
# Date                   0
# Bootcamp Time (EST)    0
# Cohort                 0
# Program                0
# Topic                  0
# dtype: int64

# %%
bootcampSchedule.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                28 non-null     object
#  1   Date                 28 non-null     object
#  2   Bootcamp Time (EST)  28 non-null     object
#  3   Cohort               28 non-null     object
#  4   Program              28 non-null     object
#  5   Topic                28 non-null     object
# dtypes: object(6)
# memory usage: 1.4+ KB

# %%
#INFERENCE from .info()
'''
The data consists of 6 features and 28 samples. 
Also it contains 6 string features
The data has been cleaned with no error visible
'''
# Out:
# '\nThe data consists of 6 features and 28 samples. \nAlso it contains 6 string features\nThe data has been cleaned with no error visible\n'

# %%
path = 'c:/datasets/Timezones.csv.'

# %%
timeZones = pd.read_csv('c:/datasets/Timezones.csv')

# %%
print(timeZones)
# Out:
#      Zone                            Time Zone Name    GMT Offset
# 0    ACDT  Australian Central Daylight Savings Time        +10:30
# 1    ACST          Australian Central Standard Time        +09:30
# 2     ACT                                 Acre Time            -5
# 3     ACT                         ASEAN Common Time  +06:30 - +09
# 4     ADT                    Atlantic Daylight Time            -3
# ..    ...                                       ...           ...
# 195   WET                     Western European Time           ±00
# 196   WIT                   Western Indonesian Time             7
# 197   WST                     Western Standard Time             8
# 198  YAKT                              Yakutsk Time             9
# 199  YEKT                        Yekaterinburg Time             5
#
# [200 rows x 3 columns]

# %%
timeZones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Zone            199 non-null    object
#  1   Time Zone Name  200 non-null    object
#  2   GMT Offset      200 non-null    object
# dtypes: object(3)
# memory usage: 4.8+ KB

# %%
#INFERENCE from .info()
'''
The data consists of 3 features and 200 samples. A sample is missing from the zone feature
Also it contains 3 string features
'''
# Out:
# '\nThe data consists of 3 features and 200 samples. A sample is missing from the zone feature\nAlso it contains 3 string features\n'

# %%
timeZones.describe()
# Out:
#        Zone          Time Zone Name GMT Offset
# count   199                     200        200
# unique  179                     199         39
# top     IST  Marquesas Islands Time          8
# freq      3                       2         17

# %%
timeZones.describe().T
# Out:
#                count unique                     top freq
# Zone             199    179                     IST    3
# Time Zone Name   200    199  Marquesas Islands Time    2
# GMT Offset       200     39                       8   17

# %%
timeZones.isnull()
# Out:
#       Zone  Time Zone Name  GMT Offset
# 0    False           False       False
# 1    False           False       False
# 2    False           False       False
# 3    False           False       False
# 4    False           False       False
# ..     ...             ...         ...
# 195  False           False       False
# 196  False           False       False
# 197  False           False       False
# 198  False           False       False
# 199  False           False       False
#
# [200 rows x 3 columns]

# %%
print(timeZones.isnull().sum())
# Out:
# Zone              1
# Time Zone Name    0
# GMT Offset        0
# dtype: int64

# %%
bool_series = pd.isnull(timeZones["Zone"]) #Searching for only true for nan values
timeZones[bool_series]
# Out:
#     Zone              Time Zone Name GMT Offset
# 182  NaN  Coordinated Universal Time        ±00

# %%
#Coordintaed Universal Time Zone is UCT thus fill the NAN with UCT
timeZones["Zone"].fillna("UCT", inplace = True)
print(timeZones)
# Out:
#      Zone                            Time Zone Name    GMT Offset
# 0    ACDT  Australian Central Daylight Savings Time        +10:30
# 1    ACST          Australian Central Standard Time        +09:30
# 2     ACT                                 Acre Time            -5
# 3     ACT                         ASEAN Common Time  +06:30 - +09
# 4     ADT                    Atlantic Daylight Time            -3
# ..    ...                                       ...           ...
# 195   WET                     Western European Time           ±00
# 196   WIT                   Western Indonesian Time             7
# 197   WST                     Western Standard Time             8
# 198  YAKT                              Yakutsk Time             9
# 199  YEKT                        Yekaterinburg Time             5
#
# [200 rows x 3 columns]

# %%
timeZones.info() #No missing value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Zone            200 non-null    object
#  1   Time Zone Name  200 non-null    object
#  2   GMT Offset      200 non-null    object
# dtypes: object(3)
# memory usage: 4.8+ KB

# %%
timeZones.describe()
# Out:
#        Zone          Time Zone Name GMT Offset
# count   200                     200        200
# unique  180                     199         39
# top     IST  Marquesas Islands Time          8
# freq      3                       2         17

# %%
timeZones.describe().T #No missing values
# Out:
#                count unique                     top freq
# Zone             200    180                     IST    3
# Time Zone Name   200    199  Marquesas Islands Time    2
# GMT Offset       200     39                       8   17

# %%
path = 'c:/datasets/countriesTimezones.csv'

# %%
countryTZ = pd.read_csv('c:/datasets/countriesTimezones.csv', encoding='latin-1')

# %%
print(countryTZ)
# Out:
#     Country Code    Country Name                       Time Zone  GMT Offset
# 0             AF     Afghanistan                      Asia/Kabul  UTC +04:36
# 1             AL         Albania                   Europe/Tirane  UTC +01:19
# 2             DZ         Algeria                  Africa/Algiers  UTC +00:12
# 3             AS  American Samoa               Pacific/Pago_Pago  UTC +12:37
# 4             AD         Andorra                  Europe/Andorra  UTC +00:06
# ..           ...             ...                             ...         ...
# 399           US   United States                America/New_York  UTC -04:56
# 400           US   United States                    America/Nome  UTC +12:58
# 401           US   United States     America/North_Dakota/Beulah  UTC -06:47
# 402           US   United States     America/North_Dakota/Center  UTC -06:45
# 403           US   United States  America/North_Dakota/New_Salem  UTC -06:45
#
# [404 rows x 4 columns]

# %%
countryTZ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  403 non-null    object
#  1   Country Name  404 non-null    object
#  2   Time Zone     404 non-null    object
#  3   GMT Offset    404 non-null    object
# dtypes: object(4)
# memory usage: 12.8+ KB

# %%
#INFERENCE from .info()
'''
The data consists of 4 features and 404 samples. A sample is missing from the country code feature
Also it contains 4 string features
'''
# Out:
# '\nThe data consists of 4 features and 404 samples. A sample is missing from the country code feature\nAlso it contains 4 string features\n'

# %%
countryTZ.describe()
# Out:
#        Country Code Country Name   Time Zone  GMT Offset
# count           403          404         404         404
# unique          232          233         404         282
# top              CA       Canada  Asia/Kabul  UTC -04:24
# freq             28           28           1          18

# %%
countryTZ.describe().T
# Out:
#              count unique         top freq
# Country Code   403    232          CA   28
# Country Name   404    233      Canada   28
# Time Zone      404    404  Asia/Kabul    1
# GMT Offset     404    282  UTC -04:24   18

# %%
countryTZ.isnull()
# Out:
#      Country Code  Country Name  Time Zone  GMT Offset
# 0           False         False      False       False
# 1           False         False      False       False
# 2           False         False      False       False
# 3           False         False      False       False
# 4           False         False      False       False
# ..            ...           ...        ...         ...
# 399         False         False      False       False
# 400         False         False      False       False
# 401         False         False      False       False
# 402         False         False      False       False
# 403         False         False      False       False
#
# [404 rows x 4 columns]

# %%
countryTZ.isnull().sum()
# Out:
# Country Code    1
# Country Name    0
# Time Zone       0
# GMT Offset      0
# dtype: int64

# %%
bool_series = pd.isnull(countryTZ["Country Code"]) #Searching for only true for nan values
countryTZ[bool_series]
# Out:
#     Country Code Country Name        Time Zone  GMT Offset
# 262          NaN      Namibia  Africa/Windhoek  UTC +01:08

# %%
#Missing value is the Namibia Country Code which is NA thus fill in missing Value with NA
countryTZ["Country Code"].fillna("NA", inplace = True)
print(countryTZ)
# Out:
#     Country Code    Country Name                       Time Zone  GMT Offset
# 0             AF     Afghanistan                      Asia/Kabul  UTC +04:36
# 1             AL         Albania                   Europe/Tirane  UTC +01:19
# 2             DZ         Algeria                  Africa/Algiers  UTC +00:12
# 3             AS  American Samoa               Pacific/Pago_Pago  UTC +12:37
# 4             AD         Andorra                  Europe/Andorra  UTC +00:06
# ..           ...             ...                             ...         ...
# 399           US   United States                America/New_York  UTC -04:56
# 400           US   United States                    America/Nome  UTC +12:58
# 401           US   United States     America/North_Dakota/Beulah  UTC -06:47
# 402           US   United States     America/North_Dakota/Center  UTC -06:45
# 403           US   United States  America/North_Dakota/New_Salem  UTC -06:45
#
# [404 rows x 4 columns]

# %%
countryTZ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  404 non-null    object
#  1   Country Name  404 non-null    object
#  2   Time Zone     404 non-null    object
#  3   GMT Offset    404 non-null    object
# dtypes: object(4)
# memory usage: 12.8+ KB

# %%
countryTZ.describe().T #No missing value in the dataset
# Out:
#              count unique         top freq
# Country Code   404    233          CA   28
# Country Name   404    233      Canada   28
# Time Zone      404    404  Asia/Kabul    1
# GMT Offset     404    282  UTC -04:24   18

# %%
path = 'c:/datasets/TimezonesDST.csv'

# %%
timezonesDST = pd.read_csv('c:/datasets/TimezonesDST.csv')

# %%
print(timezonesDST)
# Out:
#                timezone  offset  offset_dst(Day light Savings)
# 0        Africa/Abidjan       0                              0
# 1          Africa/Accra       0                              0
# 2    Africa/Addis_Ababa   10800                          10800
# 3        Africa/Algiers    3600                           3600
# 4         Africa/Asmara   10800                          10800
# ..                  ...     ...                            ...
# 583                 UTC       0                              0
# 584           Universal       0                              0
# 585                W-SU   10800                          10800
# 586                 WET       0                           3600
# 587                Zulu       0                              0
#
# [588 rows x 3 columns]

# %%
timezonesDST.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   timezone                       588 non-null    object
#  1   offset                         588 non-null    int64
#  2   offset_dst(Day light Savings)  588 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 13.9+ KB

# %%
#INFERENCE from .info()
'''
Our data has no missing values. The data consists of 3 features and 588 samples. 
Also it contains 1 string features and the rest are numeric
'''
# Out:
# '\nOur data has no missing values. The data consists of 3 features and 588 samples. \nAlso it contains 1 string features and the rest are numeric\n'

# %%
timezonesDST.describe()
# Out:
#              offset  offset_dst(Day light Savings)
# count    588.000000                     588.000000
# mean    2083.163265                    3423.979592
# std    21609.286575                   21308.591412
# min   -43200.000000                  -43200.000000
# 25%   -14400.000000                  -14400.000000
# 50%        0.000000                    3600.000000
# 75%    18000.000000                   18000.000000
# max    50400.000000                   50400.000000

# %%
timezonesDST.describe().T
# Out:
#                                count         mean           std      min  \
# offset                         588.0  2083.163265  21609.286575 -43200.0
# offset_dst(Day light Savings)  588.0  3423.979592  21308.591412 -43200.0
#
#                                    25%     50%      75%      max
# offset                        -14400.0     0.0  18000.0  50400.0
# offset_dst(Day light Savings) -14400.0  3600.0  18000.0  50400.0

# %%
import matplotlib.pyplot as plt
pd.DataFrame(timezonesDST).plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
timezonesDST['offset']
# Out:
# 0          0
# 1          0
# 2      10800
# 3       3600
# 4      10800
#        ...
# 583        0
# 584        0
# 585    10800
# 586        0
# 587        0
# Name: offset, Length: 588, dtype: int64

# %%
timezoneOffset = list(timezonesDST['offset']) #Making a list  for later use

# %%
timezoneOffset
# Out:
# [0,
#  0,
#  10800,
#  3600,
#  10800,
#  10800,
#  0,
#  3600,
#  0,
#  0,
#  7200,
#  3600,
#  7200,
#  7200,
#  0,
#  3600,
#  0,
#  0,
#  10800,
#  10800,
#  3600,
#  0,
#  0,
#  7200,
#  7200,
#  7200,
#  10800,
#  10800,
#  10800,
#  7200,
#  3600,
#  3600,
#  3600,
#  0,
#  3600,
#  7200,
#  7200,
#  3600,
#  7200,
#  7200,
#  7200,
#  10800,
#  0,
#  10800,
#  3600,
#  3600,
#  0,
#  0,
#  3600,
#  0,
#  0,
#  7200,
#  3600,
#  3600,
#  -36000,
#  -32400,
#  -14400,
#  -14400,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -10800,
#  -14400,
#  -10800,
#  -18000,
#  -36000,
#  -10800,
#  -21600,
#  -14400,
#  -10800,
#  -21600,
#  -14400,
#  -14400,
#  -18000,
#  -25200,
#  -10800,
#  -25200,
#  -14400,
#  -18000,
#  -16200,
#  -10800,
#  -10800,
#  -18000,
#  -21600,
#  -25200,
#  -18000,
#  -10800,
#  -21600,
#  -25200,
#  -14400,
#  -14400,
#  0,
#  -28800,
#  -25200,
# ...

# %%
timezonesDST['offset'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import matplotlib.pyplot as plt
timezonesDST.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
timezonesDST['offset'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #CHECKLIST
# Values are too far apart dataset needs to be rescaled
# The value for standard deviation is above 1, data needs to be restandardized
# The distribution of the data is abnormal

# %%
#RESCALING THE VALUES 
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\BABATU~1\AppData\Local\Temp/ipykernel_15808/2094368233.py in <module>
#       4 scaler = StandardScaler()
#       5
# ----> 6 model = scaler.fit(timezoneOffset)
#       7
#       8
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
# ...
